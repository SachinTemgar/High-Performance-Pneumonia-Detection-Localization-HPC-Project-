# %%
# !pip install ultralytics --upgrade --quiet

# %%
with open("data.yaml", "w") as f:
    f.write("""
path: yolo_dataset
train: images/train
val: images/train
names: ['Pneumonia']
""")
print("✅ data.yaml created")
# Out:
# ✅ data.yaml created

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.yaml")

# %%
with open("pneumonia_yolo.yaml","w") as f:
    f.write("""
train: yolo_dataset/images/train
val: yolo_dataset/images/train  
 
nc: 1
names: ['pneumonia']
""")
print("pneumonia_yolo.yaml")
# Out:
# pneumonia_yolo.yaml

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device name: Tesla P100-PCIE-12GB

# %%
# !nvidia-smi
# Out:
# Sun Apr 13 16:11:51 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla P100-PCIE-12GB           On  | 00000000:82:00.0 Off |                    0 |
# | N/A   32C    P0              24W / 250W |      0MiB / 12288MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
model.train(data="/home/temgar.s/pneumonia_yolo.yaml", epochs=10, imgsz=256, batch=16, device="cuda:0")
# Out:
# Ultralytics 8.3.107 🚀 Python-3.12.4 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-12GB, 12194MiB)
# ...
